# %% [markdown]
# 8.
#
# a)

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
import matplotlib.animation as animation
from tqdm import tqdm


Nt = 1000
Nx = 50

x = np.linspace(0.,1.,Nx)
t = np.linspace(0.,10.,Nt)

dt = t[1] - t[0]
dx = x[1] - x[0]

k=0.01
lam = k*dt/(dx**2)
print(lam)
# Out:
# 0.2403403403403404

# %% [markdown]
# b)

# %%
def ui(x):
    return np.random.rand()*0.3

def wi(x):
    return 0

def initT():
    u = np.zeros((Nt,Nx))
    u[0,:] =ui(x)
    u[:,0] = 0.1
    u[:,-1] = 0.2

    w = np.zeros((Nt,Nx))
    w[0,:] = wi(x)

    return u, w

u,w = initT()

def getSolution():

    for l in tqdm(range(1,len(t))):
        if l == 1:
            u[l,:] = u[l-1,:]
            w[l,:] = w[l-1, :]
        else:
            for i in range(1,len(x)-1):
                u[l,i] = (1-2*lam)*u[l-1,i]+lam*(u[l-1,i+1] + u[l-1,i-2]) - u[l-1,i]*(u[l-1,i]-0.2)*(1-u[l-1,i]) + w[l-1,i]
                w[l,i] = (0.03/dt)*(u[l-1,i]-0.3*w[l-1,i]) + w[l-1,i]


getSolution()

print(u)
# Out:
#   0%|                                                   | 0/999 [00:00<?, ?it/s]/var/folders/4t/bxy3v5dd0b7_yz2541rxp_wr0000gn/T/ipykernel_9009/859146914.py:28: RuntimeWarning: overflow encountered in scalar multiply
#   u[l,i] = (1-2*lam)*u[l-1,i]+lam*(u[l-1,i+1] + u[l-1,i-2]) - u[l-1,i]*(u[l-1,i]-0.2)*(1-u[l-1,i]) + w[l-1,i]
# /var/folders/4t/bxy3v5dd0b7_yz2541rxp_wr0000gn/T/ipykernel_9009/859146914.py:29: RuntimeWarning: invalid value encountered in scalar subtract
#   w[l,i] = (0.03/dt)*(u[l-1,i]-0.3*w[l-1,i]) + w[l-1,i]
# 100%|███████████████████████████████████████| 999/999 [00:00<00:00, 4174.68it/s]
# [[0.1        0.15150657 0.15150657 ... 0.15150657 0.15150657 0.2       ]
#  [0.1        0.15150657 0.15150657 ... 0.15150657 0.15150657 0.2       ]
#  [0.1        0.16939544 0.14536141 ... 0.15774052 0.16939544 0.2       ]
#  ...
#  [0.1               nan        nan ...        nan        nan 0.2       ]
#  [0.1               nan        nan ...        nan        nan 0.2       ]
#  [0.1               nan        nan ...        nan        nan 0.2       ]]

# %% [markdown]
# e)

# %%
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(1,1,1)

    
    
       
    
def Update(i):
    plot = ax.clear()
    ax.set_xlabel("distancia", fontsize=15)
    ax.set_ylabel("Voltaje", fontsize=15) 
    plot = ax.plot(x,u[i,:] ,color='blue', label=r'$u(x,%.2f)$' %(t[i]))
    plot = ax.plot(x,w[i,:] ,color='red', label=r'$u(x,%.2f)$' %(t[i]))
    plot = plt.legend(loc=0)
    return plot

Animation = animation.FuncAnimation(fig, Update, frames=len(t), init_func=init)
# Out:
# <img src="data:image/png;base64,..." width="600">
